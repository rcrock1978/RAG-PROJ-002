# %%
import os  
from dotenv import load_dotenv
load_dotenv()
print("Environment variables loaded")
# Out:
# Running cells with 'Python' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/LEGION/langchain-course/RAG_PROJECT_02/.venv/Scripts/python.exe -m pip install ipykernel -U --user --force-reinstall'
