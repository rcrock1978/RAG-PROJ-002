# %%
import sys
import os

# Activate virtual environment
venv_path = r"C:\Users\LEGION\langchain-course\RAG_PROJECT_02\.venv"
if venv_path not in sys.path:
    sys.path.insert(0, os.path.join(venv_path, "Lib", "site-packages"))

print(f"Virtual environment activated: {venv_path}")
print(f"Python executable: {sys.executable}")
# Out:
# Virtual environment activated: C:\Users\LEGION\langchain-course\RAG_PROJECT_02\.venv
# Python executable: c:\Users\LEGION\langchain-course\RAG_PROJECT_02\.venv\Scripts\python.exe

# %%
import os  
from dotenv import load_dotenv
load_dotenv()
print("Environment variables loaded")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 from dotenv import load_dotenv
#       3 load_dotenv()
#       4 print("Environment variables loaded")
#
# ModuleNotFoundError: No module named 'dotenv'
